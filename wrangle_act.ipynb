# %% [markdown]
# # WeRateDogs Twitter Data Wrangling  Project

# %% [markdown]
# ## Gather

# %%
# Importing Required Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import requests 
import os
import json
from bs4 import BeautifulSoup
# %matplotlib inline

# %%
pd.options.mode.chained_assignment = None

# %%
# Creating folder for our dataset on local system if it doesn't exist

folder_name = 'datasets'

if not os.path.exists(folder_name):
  os.makedirs(folder_name)

# %%
# Downloading dataset files from url into our local machine

url_image = 'https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv'
url_archive = 'https://d17h27t6h515a5.cloudfront.net/topher/2017/August/59a4e958_twitter-archive-enhanced/twitter-archive-enhanced.csv'

r_image = requests.get(url_image)
r_archive = requests.get(url_archive)

with open ('datasets/image_predictions.tsv', 'wb') as file:
  file.write(r_image.content)

with open ('datasets/twitter-archive-enhanced.csv', 'wb') as file:
  file.write(r_archive.content)

# %%
# Opening the tweet-json text dataset file and reading it line by line 

with open('datasets/tweet-json.txt') as file:
  tweets = []

  for line in file:
    tw = json.loads(line)
    # Appending a dictionary of selected features into the 'tweets' list 
    tweets.append({
        'tweet_id': tw['id'],
        'retweet_count':tw['retweet_count'],
        'favorite_count':tw['favorite_count']
    })

# %%
# Reading the csv,tsv and json files into pandas dataframes

df_image = pd.read_csv('datasets/image_predictions.tsv', sep='\t')
df_archive = pd.read_csv('datasets/twitter-archive-enhanced.csv')
df_tweets= pd.DataFrame(tweets)

# %% [markdown]
# ## Assessment

# %%
# Visual assessment of twitter archive dataframe

df_archive.sample(10)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 1520  690728923253055490                    NaN                  NaN
# 1416  698635131305795584                    NaN                  NaN
# 1031  745422732645535745                    NaN                  NaN
# 1087  738156290900254721                    NaN                  NaN
# 1928  674045139690631169                    NaN                  NaN
# 602   798644042770751489                    NaN                  NaN
# 2292  667160273090932737                    NaN                  NaN
# 52    882045870035918850                    NaN                  NaN
# 1125  730196704625098752                    NaN                  NaN
# 820   770414278348247044                    NaN                  NaN
#
#                       timestamp  \
# 1520  2016-01-23 02:53:03 +0000
# 1416  2016-02-13 22:29:29 +0000
# 1031  2016-06-22 01:06:43 +0000
# 1087  2016-06-01 23:52:28 +0000
# 1928  2015-12-08 01:57:39 +0000
# 602   2016-11-15 21:49:12 +0000
# 2292  2015-11-19 01:59:39 +0000
# 52    2017-07-04 01:18:17 +0000
# 1125  2016-05-11 00:43:55 +0000
# 820   2016-08-30 00:14:12 +0000
#
#                                                  source  \
# 1520  <a href="http://twitter.com/download/iphone" r...
# 1416  <a href="http://twitter.com/download/iphone" r...
# 1031  <a href="http://twitter.com/download/iphone" r...
# 1087  <a href="http://twitter.com/download/iphone" r...
# 1928  <a href="http://twitter.com/download/iphone" r...
# 602   <a href="http://twitter.com/download/iphone" r...
# 2292  <a href="http://twitter.com/download/iphone" r...
# 52    <a href="http://twitter.com/download/iphone" r...
# 1125  <a href="http://twitter.com/download/iphone" r...
# 820   <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 1520  This is Vinscent. He was just questioned about...                  NaN
# 1416  Here we are witnessing five Guatemalan Birch F...                  NaN
# 1031  We only rate dogs. Pls stop sending in non-can...                  NaN
# 1087  This is Storkson. He's wet and sad. 10/10 chee...                  NaN
# 1928  Herd of wild dogs here. Not sure what they're ...                  NaN
# 602   RT @dog_rates: This is Paull. He just stubbed ...         6.704450e+17
# 2292  This is Bradlay. He is a Ronaldinho Matsuyama ...                  NaN
# 52    This is Koko. Her owner, inspired by Barney, r...                  NaN
# 1125  This is Charles. He's camera shy. Tail longer ...                  NaN
# 820   Meet Al Cabone. He's a gangsta puppa. Rather h...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 1520                       NaN                        NaN
# 1416                       NaN                        NaN
# 1031                       NaN                        NaN
# 1087                       NaN                        NaN
# 1928                       NaN                        NaN
# 602               4.196984e+09  2015-11-28 03:31:48 +0000
# 2292                       NaN                        NaN
# 52                         NaN                        NaN
# 1125                       NaN                        NaN
# 820                        NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 1520  https://twitter.com/dog_rates/status/690728923...                 8
# 1416  https://twitter.com/dog_rates/status/698635131...                12
# 1031  https://twitter.com/dog_rates/status/745422732...                 9
# 1087  https://twitter.com/dog_rates/status/738156290...                10
# 1928  https://twitter.com/dog_rates/status/674045139...                 3
# 602   https://twitter.com/dog_rates/status/670444955...                10
# 2292  https://twitter.com/dog_rates/status/667160273...                11
# 52    https://twitter.com/dog_rates/status/882045870...                13
# 1125  https://twitter.com/dog_rates/status/730196704...                 6
# 820   https://twitter.com/dog_rates/status/770414278...                11
#
#       rating_denominator      name doggo floofer pupper puppo
# 1520                  10  Vinscent  None    None   None  None
# 1416                  10      None  None    None   None  None
# 1031                  10      very  None    None   None  None
# 1087                  10  Storkson  None    None   None  None
# 1928                  10      None  None    None   None  None
# 602                   10     Paull  None    None   None  None
# 2292                  10   Bradlay  None    None   None  None
# 52                    10      Koko  None    None   None  None
# 1125                  10   Charles  None    None   None  None
# 820                   10        Al  None    None   None  None

# %%
# Visual assessment of image prediction dataframe

df_image.sample(10)
# Out:
#                 tweet_id                                          jpg_url  \
# 106   667866724293877760  https://pbs.twimg.com/media/CUS9PlUWwAANeAD.jpg
# 1363  761334018830917632  https://pbs.twimg.com/media/CpDNQGkWEAENiYZ.jpg
# 1239  746872823977771008  https://pbs.twimg.com/media/Cl1s1p7WMAA44Vk.jpg
# 1094  719991154352222208  https://pbs.twimg.com/media/Cf3sH62VAAA-LiP.jpg
# 391   673576835670777856  https://pbs.twimg.com/media/CVkGjsxU8AA5OYX.jpg
# 1454  777189768882946048  https://pbs.twimg.com/media/Cskh9nRWYAAUxBP.jpg
# 1092  719551379208073216  https://pbs.twimg.com/media/CfxcKU6W8AE-wEx.jpg
# 1093  719704490224398336  https://pbs.twimg.com/media/CfznaXuUsAAH-py.jpg
# 1720  819347104292290561  https://pbs.twimg.com/media/C17n1nrWQAIErU3.jpg
# 940   703774238772166656  https://pbs.twimg.com/media/CcRO8FmW4AAzazk.jpg
#
#       img_num                  p1   p1_conf  p1_dog                        p2  \
# 106         1       jigsaw_puzzle  1.000000   False                prayer_rug
# 1363        1  Norwegian_elkhound  0.822936    True                  malinois
# 1239        1            Pembroke  0.540201    True                    beagle
# 1094        2    golden_retriever  0.605304    True            cocker_spaniel
# 391         1               teddy  0.255210   False        Christmas_stocking
# 1454        2           Chihuahua  0.988412    True          Mexican_hairless
# 1092        1            malamute  0.873233    True            Siberian_husky
# 1093        1        home_theater  0.059033   False              window_shade
# 1720        3          Rottweiler  0.909106    True   black-and-tan_coonhound
# 940         1  Labrador_retriever  0.990119    True  Chesapeake_Bay_retriever
#
#            p2_conf  p2_dog                      p3       p3_conf  p3_dog
# 106   1.011300e-08   False                 doormat  1.740170e-10   False
# 1363  8.615250e-02    True         German_shepherd  6.333290e-02    True
# 1239  2.078350e-01    True       Italian_greyhound  4.356490e-02    True
# 1094  1.309480e-01    True      Labrador_retriever  9.469160e-02    True
# 391   9.828520e-02   False                  pajama  7.273510e-02   False
# 1454  4.177220e-03    True                     hog  1.506580e-03   False
# 1092  7.643540e-02    True              Eskimo_dog  3.574500e-02    True
# 1093  3.829900e-02   False                 bathtub  3.552820e-02   False
# 1720  4.411980e-02    True                Doberman  3.183490e-02    True
# 940   8.025580e-03    True  curly-coated_retriever  1.242290e-03    True

# %%
# Visual assessment of tweet-json dataframe

df_tweets.sample(10)
# Out:
#                 tweet_id  retweet_count  favorite_count
# 1387  700167517596164096            836            2903
# 1297  707738799544082433           2785            4495
# 428   821107785811234820           2487           10645
# 2353  666020888022790149            532            2535
# 685   788070120937619456           3952               0
# 1530  690005060500217858           1907            4004
# 1554  688828561667567616            420            1508
# 1398  699446877801091073           2938            6515
# 87    875097192612077568           6342           27997
# 339   832215909146226688           7069               0

# %% [markdown]
# #### **Programatic assessment of the datasets**

# %%
# Assessing the twitter archive dataset

print(df_archive.shape)

df_archive.info()
# Out:
# (2356, 17)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   object
#  4   source                      2356 non-null   object
#  5   text                        2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    object
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2356 non-null   int64
#  11  rating_denominator          2356 non-null   int64
#  12  name                        2356 non-null   object
#  13  doggo                       2356 non-null   object
#  14  floofer                     2356 non-null   object
#  15  pupper                      2356 non-null   object
#  16  puppo                       2356 non-null   object
# dtypes: float64(4), int64(3), object(10)
# memory usage: 313.0+ KB

# %%
# checking for duplicates within the dataset

df_archive['tweet_id'].duplicated().sum()
# Out:
# 0

# %%
# Assessing the twitter archive dataset

print(df_image.shape)

df_image.info()
# Out:
# (2075, 12)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  2075 non-null   int64
#  1   jpg_url   2075 non-null   object
#  2   img_num   2075 non-null   int64
#  3   p1        2075 non-null   object
#  4   p1_conf   2075 non-null   float64
#  5   p1_dog    2075 non-null   bool
#  6   p2        2075 non-null   object
#  7   p2_conf   2075 non-null   float64
#  8   p2_dog    2075 non-null   bool
#  9   p3        2075 non-null   object
#  10  p3_conf   2075 non-null   float64
#  11  p3_dog    2075 non-null   bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
#checking for duplicated images in the image prediction dataset

nums_of_duplicates = df_image['jpg_url'].duplicated().sum()

print(f"There are ({nums_of_duplicates}) Duplicated images in Image Prediction Dataset")
# Out:
# There are (66) Duplicated images in Image Prediction Dataset

# %%
# Assessing the tweet counts & fovourite dataset

print(df_tweets.shape)

df_tweets.info()
# Out:
# (2354, 3)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tweet_id        2354 non-null   int64
#  1   retweet_count   2354 non-null   int64
#  2   favorite_count  2354 non-null   int64
# dtypes: int64(3)
# memory usage: 55.3 KB

# %% [markdown]
# **Quality issues** identified and to be worked on in this cleaning process are:
#
# <ol>
#   <li>We want only original tweets. No retweets and replies.</li>
#   <li>Change timestamp from string datatype to datetime datatype.</li>
#   <li>Have all the Dog stages into one column.</li>
#   <li>Strip the source table of its html tags so that only the text is left.</li>
#   <li>Removing Duplicates image rows from the image prediction Dataframe.</li>
#   <li>Removing image predictions that are not dogs from the the image prediction dataframe.</li>
#   <li>Creating a column with the most appropriete dog image recognition.</li>
#   <li>Dropping all the unecesary columns from the image recognition dataframe.</li>
# </ol>
#
# **Tidyness issues** identified and to be worked on in this cleaning process are:
# <ol>
#   <li>Remove shortened url from text column as it is redundant.</li>
#   <li>Merging the three dataframes into on dataframe for analysis.</li>
# </ol>

# %% [markdown]
# ## Clean

# %% [markdown]
# #### Define
#
# First is to make copies of all the dataframes undergoing the cleaning process

# %% [markdown]
# #### Code

# %%
# twitter archive dataset copy
archive_clean = df_archive.copy() 

# Dog image prediction dataset copy
image_clean = df_image.copy() 

# Tweet favourite & Count dataset copy
counts_clean = df_tweets.copy()

# %% [markdown]
# #### Test

# %%
# Checking the dataframes to confirm copies were made correctly

print(archive_clean.info())

archive_clean.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   object
#  4   source                      2356 non-null   object
#  5   text                        2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    object
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2356 non-null   int64
#  11  rating_denominator          2356 non-null   int64
#  12  name                        2356 non-null   object
#  13  doggo                       2356 non-null   object
#  14  floofer                     2356 non-null   object
#  15  pupper                      2356 non-null   object
#  16  puppo                       2356 non-null   object
# dtypes: float64(4), int64(3), object(10)
# memory usage: 313.0+ KB
# None
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  retweeted_status_id  \
# 0  This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1  This is Tilly. She's just checking pup on you....                  NaN
# 2  This is Archie. He is a rare Norwegian Pouncin...                  NaN
#
#    retweeted_status_user_id retweeted_status_timestamp  \
# 0                       NaN                        NaN
# 1                       NaN                        NaN
# 2                       NaN                        NaN
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892420643...                13
# 1  https://twitter.com/dog_rates/status/892177421...                13
# 2  https://twitter.com/dog_rates/status/891815181...                12
#
#    rating_denominator     name doggo floofer pupper puppo
# 0                  10  Phineas  None    None   None  None
# 1                  10    Tilly  None    None   None  None
# 2                  10   Archie  None    None   None  None

# %%
print(image_clean.info())

image_clean.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  2075 non-null   int64
#  1   jpg_url   2075 non-null   object
#  2   img_num   2075 non-null   int64
#  3   p1        2075 non-null   object
#  4   p1_conf   2075 non-null   float64
#  5   p1_dog    2075 non-null   bool
#  6   p2        2075 non-null   object
#  7   p2_conf   2075 non-null   float64
#  8   p2_dog    2075 non-null   bool
#  9   p3        2075 non-null   object
#  10  p3_conf   2075 non-null   float64
#  11  p3_dog    2075 non-null   bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB
# None
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# 0  0.156665    True    Shetland_sheepdog  0.061428    True
# 1  0.074192    True  Rhodesian_ridgeback  0.072010    True
# 2  0.138584    True           bloodhound  0.116197    True

# %%
print(counts_clean.info())

counts_clean.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tweet_id        2354 non-null   int64
#  1   retweet_count   2354 non-null   int64
#  2   favorite_count  2354 non-null   int64
# dtypes: int64(3)
# memory usage: 55.3 KB
# None
#              tweet_id  retweet_count  favorite_count
# 0  892420643555336193           8853           39467
# 1  892177421306343426           6514           33819
# 2  891815181378084864           4328           25461

# %% [markdown]
# ## Clean

# %% [markdown]
# Define
#
# *   Get only original tweets(No retweets and replies) from the archive_clean dataframe
# *   Save only the original tweets in the archive_clean dataframe
# *   Drop columns associated with retweets and replies from the archive_clean dataframe

# %% [markdown]
# ##### Code

# %%
#creating masks of no retweets and no replies

no_retweet = archive_clean['retweeted_status_id'].isna()
no_replies = archive_clean['in_reply_to_status_id'].isna()

# %%
# saving this the no_retweets & no_replies masks into the archive clean dataset
# this should give us only original tweets left in the dataframe

archive_clean = archive_clean[no_retweet & no_replies]

# %%
# Dropping columns associated with retweets and replies
drops = ['in_reply_to_status_id','in_reply_to_user_id','retweeted_status_id','retweeted_status_user_id','retweeted_status_timestamp']

archive_clean.drop(columns = drops, inplace=True)

# %% [markdown]
# ##### Test

# %%
print (archive_clean.info())

archive_clean.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2097 entries, 0 to 2355
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2097 non-null   int64
#  1   timestamp           2097 non-null   object
#  2   source              2097 non-null   object
#  3   text                2097 non-null   object
#  4   expanded_urls       2094 non-null   object
#  5   rating_numerator    2097 non-null   int64
#  6   rating_denominator  2097 non-null   int64
#  7   name                2097 non-null   object
#  8   doggo               2097 non-null   object
#  9   floofer             2097 non-null   object
#  10  pupper              2097 non-null   object
#  11  puppo               2097 non-null   object
# dtypes: int64(3), object(9)
# memory usage: 213.0+ KB
# None
#              tweet_id                  timestamp  \
# 0  892420643555336193  2017-08-01 16:23:56 +0000
# 1  892177421306343426  2017-08-01 00:17:27 +0000
# 2  891815181378084864  2017-07-31 00:18:03 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  \
# 0  This is Phineas. He's a mystical boy. Only eve...
# 1  This is Tilly. She's just checking pup on you....
# 2  This is Archie. He is a rare Norwegian Pouncin...
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892420643...                13
# 1  https://twitter.com/dog_rates/status/892177421...                13
# 2  https://twitter.com/dog_rates/status/891815181...                12
#
#    rating_denominator     name doggo floofer pupper puppo
# 0                  10  Phineas  None    None   None  None
# 1                  10    Tilly  None    None   None  None
# 2                  10   Archie  None    None   None  None

# %% [markdown]
# ### Clean

# %% [markdown]
# #### Define
#
# Change timestamp in archive_clean dataframe from string datatype to datetime datatype

# %% [markdown]
# #### Code

# %%
archive_clean['timestamp'] = pd.to_datetime(archive_clean['timestamp'])

# %% [markdown]
# #### Test

# %%
archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2097 entries, 0 to 2355
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2097 non-null   int64
#  1   timestamp           2097 non-null   datetime64[ns, UTC]
#  2   source              2097 non-null   object
#  3   text                2097 non-null   object
#  4   expanded_urls       2094 non-null   object
#  5   rating_numerator    2097 non-null   int64
#  6   rating_denominator  2097 non-null   int64
#  7   name                2097 non-null   object
#  8   doggo               2097 non-null   object
#  9   floofer             2097 non-null   object
#  10  pupper              2097 non-null   object
#  11  puppo               2097 non-null   object
# dtypes: datetime64[ns, UTC](1), int64(3), object(8)
# memory usage: 213.0+ KB

# %% [markdown]
# ### Clean
#
# #### Define
#
# Put all dog stages into one column
# * Step 1: Replace all None in dog stage columns with empty strings
# * Step 2: Create a new Dog stages column and sets it's values as the concatination of all the dog stage columns('doggo', 'floofer', 'pupper', 'puppo') in the archive_clean dataframe
# * Step 3: Make dog stage column values with more than one stage e.g 'doggopupper' as empty string as they would be treated as errors
# * Step 4: Replace all empty strings dog stage column with Nan
# * Step 5: Drop ('doggo', 'floofer', 'pupper', 'puppo') Columns

# %% [markdown]
# #### Code

# %%
# Step 1: Replacing all None in dog stages with empty strings

archive_clean[['doggo', 'floofer', 'pupper', 'puppo']] = (
                                                            archive_clean[['doggo', 'floofer', 'pupper', 'puppo']]
                                                            .replace('None','')
                                                          )

# %% [markdown]
# ##### Test

# %%
archive_clean[['doggo', 'floofer', 'pupper', 'puppo']].value_counts()
# Out:
# doggo  floofer  pupper  puppo
#                                  1761
#                 pupper            221
# doggo                              72
#                         puppo      23
#        floofer                      9
# doggo           pupper              9
#                         puppo       1
#        floofer                      1
# dtype: int64

# %% [markdown]
# #### Code

# %%
# Step 2: Creating a new Dog stages column and setting it's values to the concatination of all the dog stage columns

archive_clean['dog_stage'] = (
                               archive_clean['doggo'] 
                               + archive_clean['floofer'] 
                               + archive_clean['pupper'] 
                               + archive_clean['puppo']
                              )

# %% [markdown]
# #### Test

# %%
archive_clean['dog_stage'].value_counts()
# Out:
#                 1761
# pupper           221
# doggo             72
# puppo             23
# floofer            9
# doggopupper        9
# doggopuppo         1
# doggofloofer       1
# Name: dog_stage, dtype: int64

# %% [markdown]
# #### Code

# %%
# Step 3: Making dog stage with more than one stage e.g 'doggopupper' empty strings because they are considered errors

recognised_stages = ['doggo', 'floofer', 'pupper', 'puppo']

archive_clean['dog_stage'] = archive_clean.apply(
    lambda row: 
    '' if (row['dog_stage'] not in recognised_stages) 
    else row['dog_stage'],
    axis=1
)

# %% [markdown]
# #### Test

# %%
archive_clean['dog_stage'].value_counts()
# Out:
#            1772
# pupper      221
# doggo        72
# puppo        23
# floofer       9
# Name: dog_stage, dtype: int64

# %% [markdown]
# ##### Code

# %%
# Step 4: Replacing all empty strings in dog stage column with Nan
archive_clean['dog_stage'] = archive_clean['dog_stage'].replace('', np.nan)

# %% [markdown]
# #### Test

# %%
archive_clean['dog_stage'].value_counts()
# Out:
# pupper     221
# doggo       72
# puppo       23
# floofer      9
# Name: dog_stage, dtype: int64

# %% [markdown]
# #### Code

# %%
# Step 5: Drop ['doggo', 'floofer', 'pupper', 'puppo'] columns
columns_to_drop = ['doggo', 'floofer', 'pupper', 'puppo']

archive_clean.drop(columns=columns_to_drop, inplace=True)

# %% [markdown]
# #### Test

# %%
archive_clean.sample(10)
# Out:
#                 tweet_id                 timestamp  \
# 176   857746408056729600 2017-04-28 00:00:54+00:00
# 1556  688828561667567616 2016-01-17 21:01:41+00:00
# 1387  700505138482569216 2016-02-19 02:20:14+00:00
# 1472  693942351086120961 2016-01-31 23:42:03+00:00
# 162   860524505164394496 2017-05-05 16:00:04+00:00
# 2151  669682095984410625 2015-11-26 01:00:28+00:00
# 1357  703407252292673536 2016-02-27 02:32:12+00:00
# 1257  710296729921429505 2016-03-17 02:48:31+00:00
# 2001  672482722825261057 2015-12-03 18:29:09+00:00
# 482   815390420867969024 2017-01-01 02:53:20+00:00
#
#                                                  source  \
# 176   <a href="http://twitter.com/download/iphone" r...
# 1556  <a href="http://twitter.com/download/iphone" r...
# 1387  <a href="http://twitter.com/download/iphone" r...
# 1472  <a href="http://twitter.com/download/iphone" r...
# 162   <a href="http://twitter.com/download/iphone" r...
# 2151  <a href="http://twitter.com/download/iphone" r...
# 1357  <a href="http://twitter.com/download/iphone" r...
# 1257  <a href="http://vine.co" rel="nofollow">Vine -...
# 2001  <a href="http://twitter.com/download/iphone" r...
# 482   <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  \
# 176   Meet Thor. He doesn't have finals because he's...
# 1556  Say hello to Brad. His car probably has a spoi...
# 1387  This is Kaia. She's just cute as hell. 12/10 I...
# 1472  This is Kobe. He's a Speckled Rorschach. Reque...
# 162   This is Carl. He likes to dance. Doesn't care ...
# 2151  Meet Louie. He just pounded that bottle of win...
# 1357  This pupper doesn't understand gates. 10/10 so...
# 1257  This is Oshie. 12/10 please enjoy (vid by @cat...
# 2001  This is light saber pup. Ready to fight off ev...
# 482   Happy New Year from the squad! 13/10 for all h...
#
#                                           expanded_urls  rating_numerator  \
# 176   https://twitter.com/dog_rates/status/857746408...                13
# 1556  https://twitter.com/dog_rates/status/688828561...                 9
# 1387  https://twitter.com/dog_rates/status/700505138...                12
# 1472  https://twitter.com/dog_rates/status/693942351...                10
# 162   https://twitter.com/dog_rates/status/860524505...                13
# 2151  https://twitter.com/dog_rates/status/669682095...                 9
# 1357  https://twitter.com/dog_rates/status/703407252...                10
# 1257                      https://vine.co/v/iw9hUFAMerV                12
# 2001  https://twitter.com/dog_rates/status/672482722...                10
# 482   https://twitter.com/dog_rates/status/815390420...                13
#
#       rating_denominator   name dog_stage
# 176                   10   Thor       NaN
# 1556                  10   Brad       NaN
# 1387                  10   Kaia       NaN
# 1472                  10   Kobe       NaN
# 162                   10   Carl       NaN
# 2151                  10  Louie       NaN
# 1357                  10   None    pupper
# 1257                  10  Oshie       NaN
# 2001                  10  light       NaN
# 482                   10   None       NaN

# %% [markdown]
# ### Clean
#
# #### Define
#
# * Strip the source column in archive_clean dataframe of its html tags so that only the text is left.

# %% [markdown]
# #### Code

# %%
archive_clean['source'] = archive_clean['source'].str.replace(r'<[^<>]*>', '', regex=True)

# %% [markdown]
# #### Test

# %%
archive_clean['source'].value_counts()
# Out:
# Twitter for iPhone     1964
# Vine - Make a Scene      91
# Twitter Web Client       31
# TweetDeck                11
# Name: source, dtype: int64

# %% [markdown]
# ### Clean
#
# #### Define
#
# * Remove Duplicate image rows from the image prediction Dataframe.

# %% [markdown]
# #### Code

# %%
image_clean.drop_duplicates(subset= ['jpg_url'], inplace=True)

# %% [markdown]
# #### Test

# %%
image_clean['jpg_url'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Clean
#
# #### Define
# Remove image predictions that are not dogs from the the image prediction dataframe
#
# Steps to take:
#
# * Convert the image prediction columns(p1,p2,p3) to lower case and underscore seperated string for uniformity and better conform to pythonic string values.
# * Scrape a robust list of all extant dog breeds from wikipedia using beautiful soup and it save as a dataframe.
# * Clean up wiki dog breeds datatframe values to conform with image prediction columns(p1,p2,p3) values.
# * Check if prediction columns p1 or p2 or p3 are dog breeds that corresponds with the wiki dog breeds dataframe values and save the best prediction into  a new column.
# * Drop all image predictions that are not dogs

# %% [markdown]
# #### Code

# %%
# Converting p1,p2,p2 columns to lower and underscore seperated strings

image_clean[['p1','p2','p3']] = image_clean[['p1','p2','p3']].applymap(lambda s: s.lower())

# %% [markdown]
# #### Test

# %%
image_clean.sample(2)
# Out:
#                 tweet_id                                          jpg_url  \
# 1300  752660715232722944  https://pbs.twimg.com/media/CnH87L6XYAAF7I_.jpg
# 1965  867421006826221569  https://pbs.twimg.com/media/DAmyy8FXYAIH8Ty.jpg
#
#       img_num          p1   p1_conf  p1_dog              p2   p2_conf  p2_dog  \
# 1300        2       goose  0.339324   False  english_setter  0.050512    True
# 1965        1  eskimo_dog  0.616457    True  siberian_husky  0.381330    True
#
#             p3   p3_conf  p3_dog
# 1300    basset  0.049093    True
# 1965  malamute  0.001670    True

# %% [markdown]
# #### Define
#
# * Scrape a robust list of all extant dog breeds from wikipedia using beautiful soup and it save as a dataframe.

# %% [markdown]
# #### Code

# %%
# Getting a list of dog breeds from wikipedia
dog_breed_url = 'https://en.wikipedia.org/wiki/List_of_dog_breeds'
response = requests.get(dog_breed_url)

# %%
# Setting response request to variable
page_contents = response.text

# %%
# Saving the response text as a file on local system
with open('datasets/wiki_List_of_dog_breeds.html','w') as file: 
    file.write(page_contents)

# %%
# Using beautiful soup to parse the wiki web page
soup = BeautifulSoup(page_contents, 'html.parser')

# %%
# Getting only the extant dog breed list from the html file.
dog_breed_list = []
div_breeds = soup.find_all("div", {"class": "div-col"})[0:4]

for breed in div_breeds:
  for b_temp in breed.find_all('li'):
    dog_breed_list.append(b_temp.text)

dog_breed_list[:5]
# Out:
# ['Affenpinscher[7]',
#  'Afghan Hound[8]',
#  'Africanis[9]',
#  'Aidi[10]',
#  'Airedale Terrier[11]']

# %%
# Saving the list into a dataframe

breeds = {'breeds': dog_breed_list }
df_breeds = pd.DataFrame(data=breeds)

# %% [markdown]
# #### Test

# %%
df_breeds.head()
# Out:
#                  breeds
# 0      Affenpinscher[7]
# 1       Afghan Hound[8]
# 2          Africanis[9]
# 3              Aidi[10]
# 4  Airedale Terrier[11]

# %% [markdown]
# #### Define
# * Clean up wiki dog breeds datatframe values to conform with image prediction columns(p1,p2,p3) values.

# %%
# clean up breeds column

df_breeds['breeds'] = (
                        df_breeds['breeds']
                        .str.replace(r"\[\d*?\]", "", regex=True)
                        .str.replace(' ', '_')
                        .str.lower()
                      )

# %% [markdown]
# #### Test

# %%
df_breeds.head()
# Out:
#              breeds
# 0     affenpinscher
# 1      afghan_hound
# 2         africanis
# 3              aidi
# 4  airedale_terrier

# %% [markdown]
# #### Define
#
#
# *   Check if prediction columns p1 or p2 or p3 are dog breeds that corresponds with the wiki dog breeds dataframe values and save the best prediction into a new column.

# %%
# Creating a function to check if the row contains a known dog breed 
# returning the best prediction
# if row doesn't contain a dog breed, funtion returns the string "None"

def check_breeds(df):
  if (df['p1'] in df_breeds['breeds'].values.tolist()) | (df['p1_dog'] == True):
    return df.p1
  elif (df['p2'] in df_breeds['breeds'].values.tolist()) | (df['p2_dog'] == True):
    return df.p2
  elif (df['p3'] in df_breeds['breeds'].values.tolist()) | (df['p3_dog'] == True):
    return df.p3
  else:
    return "None"

# %%
#Apply the function and save the best prediction to a new column " dog_breed_p"

image_clean['dog_breed_p'] = image_clean.apply(check_breeds, axis=1)

# %% [markdown]
# #### Test

# %%
image_clean.sample(5)
# Out:
#                 tweet_id                                          jpg_url  \
# 984   707420581654872064  https://pbs.twimg.com/media/CdFDQVgWIAArslx.jpg
# 1163  735137028879360001  https://pbs.twimg.com/media/CjO7OfeWgAAUQy-.jpg
# 1228  745422732645535745  https://pbs.twimg.com/media/ClhGBCAWIAAFCsz.jpg
# 1977  870374049280663552  https://pbs.twimg.com/media/DBQwlFCXkAACSkI.jpg
# 1281  750147208377409536  https://pbs.twimg.com/media/CmkO57iXgAEOxX9.jpg
#
#       img_num                  p1   p1_conf  p1_dog                p2  \
# 984         1                 ram  0.518215   False            kuvasz
# 1163        1        walker_hound  0.413535    True            beagle
# 1228        1  labrador_retriever  0.663800    True  golden_retriever
# 1977        1    golden_retriever  0.841001    True    great_pyrenees
# 1281        1                 pug  0.977765    True       boston_bull
#
#        p2_conf  p2_dog                  p3   p3_conf  p3_dog  \
# 984   0.149391    True      great_pyrenees  0.106003    True
# 1163  0.233891    True    english_foxhound  0.164943    True
# 1228  0.308261    True            ice_bear  0.004269   False
# 1977  0.099278    True  labrador_retriever  0.032621    True
# 1281  0.004794    True      french_bulldog  0.004573    True
#
#              dog_breed_p
# 984               kuvasz
# 1163        walker_hound
# 1228  labrador_retriever
# 1977    golden_retriever
# 1281                 pug

# %%
# Confirming that the "None" values are not dog breeds

image_clean[image_clean['dog_breed_p'] == "None"]
# Out:
#                 tweet_id                                            jpg_url  \
# 6     666051853826850816    https://pbs.twimg.com/media/CT5KoJ1WoAAJash.jpg
# 17    666104133288665088    https://pbs.twimg.com/media/CT56LSZWoAAlJj2.jpg
# 18    666268910803644416    https://pbs.twimg.com/media/CT8QCd1WEAADXws.jpg
# 21    666293911632134144    https://pbs.twimg.com/media/CT8mx7KW4AEQu8N.jpg
# 25    666362758909284353    https://pbs.twimg.com/media/CT9lXGsUcAAyUFt.jpg
# ...                  ...                                                ...
# 2021  880935762899988482    https://pbs.twimg.com/media/DDm2Z5aXUAEDS2u.jpg
# 2022  881268444196462592    https://pbs.twimg.com/media/DDrk-f9WAAI-WQv.jpg
# 2046  886680336477933568    https://pbs.twimg.com/media/DE4fEDzWAAAyHMM.jpg
# 2052  887517139158093824  https://pbs.twimg.com/ext_tw_video_thumb/88751...
# 2074  892420643555336193    https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
#
#       img_num                p1   p1_conf  p1_dog               p2   p2_conf  \
# 6           1        box_turtle  0.933012   False       mud_turtle  0.045885
# 17          1               hen  0.965932   False             cock  0.033919
# 18          1  desktop_computer  0.086502   False             desk  0.085547
# 21          1  three-toed_sloth  0.914671   False            otter  0.015250
# 25          1        guinea_pig  0.996496   False            skunk  0.002402
# ...       ...               ...       ...     ...              ...       ...
# 2021        1       street_sign  0.251801   False         umbrella  0.115123
# 2022        1            tusker  0.473303   False  indian_elephant  0.245646
# 2046        1       convertible  0.738995   False       sports_car  0.139952
# 2052        1         limousine  0.130432   False        tow_truck  0.029175
# 2074        1            orange  0.097049   False            bagel  0.085851
#
#       p2_dog              p3   p3_conf  p3_dog dog_breed_p
# 6      False        terrapin  0.017885   False        None
# 17     False       partridge  0.000052   False        None
# 18     False        bookcase  0.079480   False        None
# 21     False  great_grey_owl  0.013207   False        None
# 25     False         hamster  0.000461   False        None
# ...      ...             ...       ...     ...         ...
# 2021   False   traffic_light  0.069534   False        None
# 2022   False            ibex  0.055661   False        None
# 2046   False       car_wheel  0.044173   False        None
# 2052   False   shopping_cart  0.026321   False        None
# 2074   False          banana  0.076110   False        None
#
# [318 rows x 13 columns]

# %% [markdown]
# #### Define
#
# * Droping all image predictions that are not dogs

# %% [markdown]
# #### Code

# %%
# "None" values in dog_breed_p constitute rows that are not dogs 
image_clean.drop(image_clean[image_clean['dog_breed_p'] == "None"].index, inplace = True)

# %% [markdown]
# #### Test

# %%
image_clean.shape
# Out:
# (1691, 13)

# %% [markdown]
# ### Define
# * Drop columns p1,p2,p3 and their associated confidence columns from image prediction dataframe as they have become redundant.

# %% [markdown]
# ##### Code

# %%
image_clean.drop(columns = ['p1','p1_conf','p1_dog','p2','p2_conf','p2_dog','p3','p3_conf','p3_dog'], inplace=True)

# %% [markdown]
# #### Test

# %%
image_clean.sample(2)
# Out:
#                 tweet_id                                            jpg_url  \
# 1997  875021211251597312    https://pbs.twimg.com/media/DCSzF3NVoAAPzT4.jpg
# 2023  881536004380872706  https://pbs.twimg.com/ext_tw_video_thumb/88153...
#
#       img_num                  dog_breed_p
# 1997        2  west_highland_white_terrier
# 2023        1                      samoyed

# %% [markdown]
# ## Tidyness Issues

# %% [markdown]
# ### Define
# * Remove shortened url from text column as it is redundant.

# %% [markdown]
# #### Code

# %%
#Removing url link from the text column values

archive_clean['text'] = archive_clean['text'].str.replace('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', '', regex=True)

# %% [markdown]
# #### Test

# %%
archive_clean.head(2)
# Out:
#              tweet_id                 timestamp              source  \
# 0  892420643555336193 2017-08-01 16:23:56+00:00  Twitter for iPhone
# 1  892177421306343426 2017-08-01 00:17:27+00:00  Twitter for iPhone
#
#                                                 text  \
# 0  This is Phineas. He's a mystical boy. Only eve...
# 1  This is Tilly. She's just checking pup on you....
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892420643...                13
# 1  https://twitter.com/dog_rates/status/892177421...                13
#
#    rating_denominator     name dog_stage
# 0                  10  Phineas       NaN
# 1                  10    Tilly       NaN

# %% [markdown]
# ### Define
# * Merge archive_clean dataframe with the image prediction dataframe

# %% [markdown]
# #### Code

# %%
# creating a new dataframe from merged archive_clean dataframe and image prediction dataframe

df = archive_clean.merge(image_clean[['dog_breed_p','jpg_url', 'tweet_id']])

# %% [markdown]
# #### Test

# %%
print(df.info())

df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1666 entries, 0 to 1665
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            1666 non-null   int64
#  1   timestamp           1666 non-null   datetime64[ns, UTC]
#  2   source              1666 non-null   object
#  3   text                1666 non-null   object
#  4   expanded_urls       1666 non-null   object
#  5   rating_numerator    1666 non-null   int64
#  6   rating_denominator  1666 non-null   int64
#  7   name                1666 non-null   object
#  8   dog_stage           248 non-null    object
#  9   dog_breed_p         1666 non-null   object
#  10  jpg_url             1666 non-null   object
# dtypes: datetime64[ns, UTC](1), int64(3), object(7)
# memory usage: 156.2+ KB
# None
#              tweet_id                 timestamp              source  \
# 0  892177421306343426 2017-08-01 00:17:27+00:00  Twitter for iPhone
# 1  891815181378084864 2017-07-31 00:18:03+00:00  Twitter for iPhone
# 2  891689557279858688 2017-07-30 15:58:51+00:00  Twitter for iPhone
# 3  891327558926688256 2017-07-29 16:00:24+00:00  Twitter for iPhone
# 4  891087950875897856 2017-07-29 00:08:17+00:00  Twitter for iPhone
#
#                                                 text  \
# 0  This is Tilly. She's just checking pup on you....
# 1  This is Archie. He is a rare Norwegian Pouncin...
# 2  This is Darla. She commenced a snooze mid meal...
# 3  This is Franklin. He would like you to stop ca...
# 4  Here we have a majestic great white breaching ...
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892177421...                13
# 1  https://twitter.com/dog_rates/status/891815181...                12
# 2  https://twitter.com/dog_rates/status/891689557...                13
# 3  https://twitter.com/dog_rates/status/891327558...                12
# 4  https://twitter.com/dog_rates/status/891087950...                13
#
#    rating_denominator      name dog_stage               dog_breed_p  \
# 0                  10     Tilly       NaN                 chihuahua
# 1                  10    Archie       NaN                 chihuahua
# 2                  10     Darla       NaN        labrador_retriever
# 3                  10  Franklin       NaN                    basset
# 4                  10      None       NaN  chesapeake_bay_retriever
#
#                                            jpg_url
# 0  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
# 1  https://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg
# 2  https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg
# 3  https://pbs.twimg.com/media/DF6hr6BUMAAzZgT.jpg
# 4  https://pbs.twimg.com/media/DF3HwyEWsAABqE6.jpg

# %% [markdown]
# #### Define
# * Merge df dataframe with tweets count & favourite dataset

# %% [markdown]
# ##### Code

# %%
df = df.merge(df_tweets[['retweet_count','favorite_count', 'tweet_id']])

# %% [markdown]
# ##### Test

# %%
print(df.info())


df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1666 entries, 0 to 1665
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            1666 non-null   int64
#  1   timestamp           1666 non-null   datetime64[ns, UTC]
#  2   source              1666 non-null   object
#  3   text                1666 non-null   object
#  4   expanded_urls       1666 non-null   object
#  5   rating_numerator    1666 non-null   int64
#  6   rating_denominator  1666 non-null   int64
#  7   name                1666 non-null   object
#  8   dog_stage           248 non-null    object
#  9   dog_breed_p         1666 non-null   object
#  10  jpg_url             1666 non-null   object
#  11  retweet_count       1666 non-null   int64
#  12  favorite_count      1666 non-null   int64
# dtypes: datetime64[ns, UTC](1), int64(5), object(7)
# memory usage: 182.2+ KB
# None
#              tweet_id                 timestamp              source  \
# 0  892177421306343426 2017-08-01 00:17:27+00:00  Twitter for iPhone
# 1  891815181378084864 2017-07-31 00:18:03+00:00  Twitter for iPhone
# 2  891689557279858688 2017-07-30 15:58:51+00:00  Twitter for iPhone
# 3  891327558926688256 2017-07-29 16:00:24+00:00  Twitter for iPhone
# 4  891087950875897856 2017-07-29 00:08:17+00:00  Twitter for iPhone
#
#                                                 text  \
# 0  This is Tilly. She's just checking pup on you....
# 1  This is Archie. He is a rare Norwegian Pouncin...
# 2  This is Darla. She commenced a snooze mid meal...
# 3  This is Franklin. He would like you to stop ca...
# 4  Here we have a majestic great white breaching ...
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892177421...                13
# 1  https://twitter.com/dog_rates/status/891815181...                12
# 2  https://twitter.com/dog_rates/status/891689557...                13
# 3  https://twitter.com/dog_rates/status/891327558...                12
# 4  https://twitter.com/dog_rates/status/891087950...                13
#
#    rating_denominator      name dog_stage               dog_breed_p  \
# 0                  10     Tilly       NaN                 chihuahua
# 1                  10    Archie       NaN                 chihuahua
# 2                  10     Darla       NaN        labrador_retriever
# 3                  10  Franklin       NaN                    basset
# 4                  10      None       NaN  chesapeake_bay_retriever
#
#                                            jpg_url  retweet_count  \
# 0  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg           6514
# 1  https://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg           4328
# 2  https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg           8964
# 3  https://pbs.twimg.com/media/DF6hr6BUMAAzZgT.jpg           9774
# 4  https://pbs.twimg.com/media/DF3HwyEWsAABqE6.jpg           3261
#
#    favorite_count
# 0           33819
# 1           25461
# 2           42908
# 3           41048
# 4           20562

# %% [markdown]
# ### Clean
#
# #### Define
#
# * clean-up on df dataframe: Remove jpg_url column from dataframe

# %% [markdown]
# #### Code

# %%
df.drop(columns=['jpg_url'], inplace=True)

# %% [markdown]
# #### Test

# %%
df.sample(5)
# Out:
#                 tweet_id                 timestamp              source  \
# 385   799422933579902976 2016-11-18 01:24:14+00:00  Twitter for iPhone
# 36    883482846933004288 2017-07-08 00:28:19+00:00  Twitter for iPhone
# 968   699434518667751424 2016-02-16 03:25:58+00:00  Twitter for iPhone
# 1242  677700003327029250 2015-12-18 04:00:46+00:00  Twitter for iPhone
# 1202  679844490799091713 2015-12-24 02:02:12+00:00  Twitter for iPhone
#
#                                                    text  \
# 385   This is Longfellow (prolly sophisticated). He'...
# 36    This is Bella. She hopes her smile made you sm...
# 968   I know this is a tad late but here's a wonderf...
# 1242  This is Ralph. He's an interpretive dancer. 10...
# 1202  This is Willie. He's floating away and needs y...
#
#                                           expanded_urls  rating_numerator  \
# 385   https://twitter.com/dog_rates/status/799422933...                12
# 36    https://twitter.com/dog_rates/status/883482846...                 5
# 968   https://twitter.com/dog_rates/status/699434518...                12
# 1242  https://twitter.com/dog_rates/status/677700003...                10
# 1202  https://twitter.com/dog_rates/status/679844490...                10
#
#       rating_denominator        name dog_stage         dog_breed_p  \
# 385                   10  Longfellow       NaN  miniature_pinscher
# 36                    10       Bella       NaN    golden_retriever
# 968                   10        None    pupper    golden_retriever
# 1242                  10       Ralph       NaN      siberian_husky
# 1202                  10      Willie       NaN            airedale
#
#       retweet_count  favorite_count
# 385            2213            8965
# 36            10407           46860
# 968             577            2384
# 1242           1622            3689
# 1202            887            2593

# %% [markdown]
# ### **Getting a statistical overview of the merged dataframe**

# %%
df.describe()
# Out:
#            tweet_id  rating_numerator  rating_denominator  retweet_count  \
# count  1.666000e+03       1666.000000         1666.000000    1666.000000
# mean   7.395044e+17         11.388355           10.468788    2834.429772
# std    6.801710e+16          7.489081            6.343940    4831.960790
# min    6.660209e+17          0.000000            2.000000      16.000000
# 25%    6.775503e+17         10.000000           10.000000     650.500000
# 50%    7.141778e+17         11.000000           10.000000    1440.500000
# 75%    7.931921e+17         12.000000           10.000000    3261.000000
# max    8.921774e+17        165.000000          150.000000   79515.000000
#
#        favorite_count
# count     1666.000000
# mean      9288.184274
# std      12641.538890
# min         81.000000
# 25%       2176.000000
# 50%       4464.000000
# 75%      11734.750000
# max     132810.000000

# %% [markdown]
# It seems that there are some unusual data in the rating rating_denominator column. The value should be around 10 but we have values as low as 2 and as high as 150
#
# Investigating further to determine if some of this values are errors in the dataset or just outliers

# %%
too_low= df['rating_denominator'] < 10

df[too_low]
# Out:
#                 tweet_id                 timestamp              source  \
# 345   810984652412424192 2016-12-19 23:06:23+00:00  Twitter for iPhone
# 1648  666287406224695296 2015-11-16 16:11:11+00:00  Twitter for iPhone
#
#                                                    text  \
# 345   Meet Sam. She smiles 24/7 &amp; secretly aspir...
# 1648  This is an Albanian 3 1/2 legged  Episcopalian...
#
#                                           expanded_urls  rating_numerator  \
# 345   https://www.gofundme.com/sams-smile,https://tw...                24
# 1648  https://twitter.com/dog_rates/status/666287406...                 1
#
#       rating_denominator name dog_stage       dog_breed_p  retweet_count  \
# 345                    7  Sam       NaN  golden_retriever           1655
# 1648                   2   an       NaN       maltese_dog             71
#
#       favorite_count
# 345             5927
# 1648             152

# %% [markdown]
# After investigating the low values, it clear they are false rating values. Since this observation are just 2, it is okay to use the mean rating for observation at index '345' as it has no known associated rating after further investigation while I use the correctly found rating for observation at index '1648'.

# %% [markdown]
# ### Clean
#
# #### Define
#
# * Fill in rating values at index '345' with mean, rounded to the nearest int
# * Fill in rating values at index '1648' with correct values found at tweet text

# %% [markdown]
# ##### Code

# %%
df.loc[345,'rating_numerator'] = df['rating_numerator'].mean().round().astype('int64')
df.loc[345,'rating_denominator'] = df['rating_denominator'].mean().round().astype('int64')

df.loc[1648,'rating_numerator'] = 9
df.loc[1648,'rating_denominator'] = 10

# %% [markdown]
# #### Test

# %%
df.iloc[[345,1648]]
# Out:
#                 tweet_id                 timestamp              source  \
# 345   810984652412424192 2016-12-19 23:06:23+00:00  Twitter for iPhone
# 1648  666287406224695296 2015-11-16 16:11:11+00:00  Twitter for iPhone
#
#                                                    text  \
# 345   Meet Sam. She smiles 24/7 &amp; secretly aspir...
# 1648  This is an Albanian 3 1/2 legged  Episcopalian...
#
#                                           expanded_urls  rating_numerator  \
# 345   https://www.gofundme.com/sams-smile,https://tw...                11
# 1648  https://twitter.com/dog_rates/status/666287406...                 9
#
#       rating_denominator name dog_stage       dog_breed_p  retweet_count  \
# 345                   10  Sam       NaN  golden_retriever           1655
# 1648                  10   an       NaN       maltese_dog             71
#
#       favorite_count
# 345             5927
# 1648             152

# %% [markdown]
# Also further investigation of rating with denominators higher than 10 is needed to ascertain if they are actual errors in the datasetor are simply part of weratedogs ingenuity

# %%
too_high= ((df['rating_denominator'] > 10) & (df['rating_denominator'] <= 150))

df[too_high]
# Out:
#                 tweet_id                 timestamp              source  \
# 289   820690176645140481 2017-01-15 17:52:40+00:00  Twitter for iPhone
# 589   758467244762497024 2016-07-28 01:00:57+00:00  Twitter for iPhone
# 705   740373189193256964 2016-06-08 02:41:38+00:00  Twitter for iPhone
# 786   722974582966214656 2016-04-21 02:25:47+00:00  Twitter for iPhone
# 816   716439118184652801 2016-04-03 01:36:11+00:00  Twitter for iPhone
# 835   713900603437621249 2016-03-27 01:29:02+00:00  Twitter for iPhone
# 854   710658690886586372 2016-03-18 02:46:49+00:00  Twitter for iPhone
# 871   709198395643068416 2016-03-14 02:04:08+00:00  Twitter for iPhone
# 929   704054845121142784 2016-02-28 21:25:30+00:00  Twitter for iPhone
# 994   697463031882764288 2016-02-10 16:51:59+00:00  Twitter for iPhone
# 1133  684222868335505415 2016-01-05 04:00:18+00:00  Twitter for iPhone
# 1156  682962037429899265 2016-01-01 16:30:13+00:00  Twitter for iPhone
# 1241  677716515794329600 2015-12-18 05:06:23+00:00  Twitter for iPhone
# 1290  675853064436391936 2015-12-13 01:41:41+00:00  Twitter for iPhone
#
#                                                    text  \
# 289   The floofs have been released I repeat the flo...
# 589   Why does this never happen at my front door......
# 705   After so many requests, this is Bretagne. She ...
# 786           Happy 4/20 from the squad! 13/10 for all
# 816   This is Bluebert. He just saw that both #Final...
# 835   Happy Saturday here's 9 puppers on a bench. 99...
# 854   Here's a brigade of puppers. All look very pre...
# 871   From left to right:\nCletus, Jerome, Alejandro...
# 929   Here is a whole flock of puppers.  60/50 I'll ...
# 994   Happy Wednesday here's a bucket of pups. 44/40...
# 1133  Someone help the girl is being mugged. Several...
# 1156  This is Darrel. He just robbed a 7/11 and is i...
# 1241    IT'S PUPPERGEDDON. Total of 144/120 ...I think
# 1290  Here we have an entire platoon of puppers. Tot...
#
#                                           expanded_urls  rating_numerator  \
# 289   https://twitter.com/dog_rates/status/820690176...                84
# 589   https://twitter.com/dog_rates/status/758467244...               165
# 705   https://twitter.com/dog_rates/status/740373189...                 9
# 786   https://twitter.com/dog_rates/status/722974582...                 4
# 816   https://twitter.com/dog_rates/status/716439118...                50
# 835   https://twitter.com/dog_rates/status/713900603...                99
# 854   https://twitter.com/dog_rates/status/710658690...                80
# 871   https://twitter.com/dog_rates/status/709198395...                45
# 929   https://twitter.com/dog_rates/status/704054845...                60
# 994   https://twitter.com/dog_rates/status/697463031...                44
# 1133  https://twitter.com/dog_rates/status/684222868...               121
# 1156  https://twitter.com/dog_rates/status/682962037...                 7
# 1241  https://twitter.com/dog_rates/status/677716515...               144
# 1290  https://twitter.com/dog_rates/status/675853064...                88
#
#       rating_denominator      name dog_stage                  dog_breed_p  \
# 289                   70      None       NaN  west_highland_white_terrier
# 589                  150      None       NaN           labrador_retriever
# 705                   11      None       NaN             golden_retriever
# 786                   20      None       NaN                   great_dane
# 816                   50  Bluebert       NaN               siberian_husky
# 835                   90      None       NaN             golden_retriever
# 854                   80      None       NaN  soft-coated_wheaten_terrier
# 871                   50      None       NaN                       borzoi
# 929                   50         a       NaN               great_pyrenees
# 994                   40      None       NaN           labrador_retriever
# 1133                 110      None       NaN  soft-coated_wheaten_terrier
# 1156                  11    Darrel       NaN                    chihuahua
# 1241                 120      None       NaN                         chow
# 1290                  80      None       NaN           labrador_retriever
#
#       retweet_count  favorite_count
# 289            3716           13518
# 589            2539            5316
# 705            9220           20648
# 786            1764            4493
# 816             247            2574
# 835             829            3062
# 854             636            2529
# 871             721            2634
# 929            1028            3201
# 994            1552            3748
# 1133           1563            4225
# 1156          15043           26239
# 1241           1104            3323
# 1290           1460            2927

# %% [markdown]
# After investigating the seeminly high values further, it was clear that majority of the values are not errors but just part of weratedogs ingenuity.
#
# The only observations that have errors in their ratings are observations at indexes '705', 786 , 816 , 1156.
#
# As done with the extremely low values, since this are just 4 entries, I  can simply input the correct rating values.

# %% [markdown]
# ### Clean
#
# #### Define
# * Fill in rating values at index '705' , '786' , '816' , '1156' with correct values found at tweet text

# %% [markdown]
# #### Code

# %%
df.loc[705,'rating_numerator'] = 14
df.loc[705,'rating_denominator'] = 10

df.loc[786,'rating_numerator'] = 13
df.loc[786,'rating_denominator'] = 10

df.loc[816,'rating_numerator'] = 11
df.loc[816,'rating_denominator'] = 10

df.loc[705,'rating_numerator'] = 10
df.loc[705,'rating_denominator'] = 10

# %% [markdown]
# #### Test

# %%
df.iloc[[705,786,816,1156]]
# Out:
#                 tweet_id                 timestamp              source  \
# 705   740373189193256964 2016-06-08 02:41:38+00:00  Twitter for iPhone
# 786   722974582966214656 2016-04-21 02:25:47+00:00  Twitter for iPhone
# 816   716439118184652801 2016-04-03 01:36:11+00:00  Twitter for iPhone
# 1156  682962037429899265 2016-01-01 16:30:13+00:00  Twitter for iPhone
#
#                                                    text  \
# 705   After so many requests, this is Bretagne. She ...
# 786           Happy 4/20 from the squad! 13/10 for all
# 816   This is Bluebert. He just saw that both #Final...
# 1156  This is Darrel. He just robbed a 7/11 and is i...
#
#                                           expanded_urls  rating_numerator  \
# 705   https://twitter.com/dog_rates/status/740373189...                10
# 786   https://twitter.com/dog_rates/status/722974582...                13
# 816   https://twitter.com/dog_rates/status/716439118...                11
# 1156  https://twitter.com/dog_rates/status/682962037...                 7
#
#       rating_denominator      name dog_stage       dog_breed_p  retweet_count  \
# 705                   10      None       NaN  golden_retriever           9220
# 786                   10      None       NaN        great_dane           1764
# 816                   10  Bluebert       NaN    siberian_husky            247
# 1156                  11    Darrel       NaN         chihuahua          15043
#
#       favorite_count
# 705            20648
# 786             4493
# 816             2574
# 1156           26239

# %% [markdown]
# ## Save the merged and Cleaned dataframe to system

# %%
df.to_csv('datasets/twitter_archive_master.csv', index=False)

# %% [markdown]
# ## **Analysing the data**

# %% [markdown]
# ## **Question to be Answered**
#
# <ol>
#   <li>What are the top 5 most favourited dog breeds on average</li>
#   <li>Which dog stage has the highest retweet count on average</li>
#   <li>What is Relationship between retweets and favourites</li>
#
# </ol>

# %% [markdown]
# #### What are the top 5 most favourited dog breeds on average

# %%
mean_favorite_by_breed = df.groupby('dog_breed_p').favorite_count.mean().sort_values(ascending=False).head(5).reset_index()

mean_favorite_by_breed.columns=['breed', 'count']

# %%
# Formating the breed values to appear nicer in the chart
mean_favorite_by_breed['breed'] = (
                        mean_favorite_by_breed['breed']
                        .str.replace('_', ' ')
                        .str.title()
                      )

# %%
fig = px.bar(
    mean_favorite_by_breed, 
    x='breed',
    y='count',
    labels={'breed': 'Dog Breeds', 'count': 'Average Favorite Count'} 
    )

fig.update_layout(
    title='Top 5 most favourited dog breeds on Average',
    title_x=0.5,
    xaxis_tickfont_size=12,
    xaxis_titlefont_size=16,
    yaxis_titlefont_size=16,
    )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="207ef5cb-dd72-4ea8-9f60-2f3a146ef3ae" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("207ef5cb-dd72-4ea8-9f60-2f3a146ef3ae")) {                    Plotly.newPlot(                        "207ef5cb-dd72-4ea8-9f60-2f3a146ef3ae",                        [{"alignmentgroup":"True","hovertemplate":"Dog Breeds=%{x}<br>Average Favorite Count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Saluki","Bedlington Terrier","French Bulldog","Bouvier Des Flandres","Afghan Hound"],"xaxis":"x","y":[24060.0,21153.166666666668,18416.8064516129,18032.0,17326.666666666668],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pi ...

# %% [markdown]
# It appears the top 5 breeds by Average favorite count are
# <ol>
#
#   <b><li> Saluki</li>
#   <li>Bedlington Terrier</li>
#   <li>French Bulldog</li>
#   <li>Bouvier Des Flandres</li>
#   <li>Afghan Hound </li> </b>
#
# </ol>

# %% [markdown]
# ## Q2: Which dog stage has the highest retweet count on average

# %%
mean_retweet_by_dog_stage = df.groupby('dog_stage').retweet_count.mean().sort_values(ascending=False)

mean_retweet_by_dog_stage[:1]
# Out:
# dog_stage
# doggo    7059.87037
# Name: retweet_count, dtype: float64

# %% [markdown]
# It appears on average people retweeted dogs that are in the **'Doggo'** stage than any other dog stage

# %% [markdown]
# ![DFrEyVuW0AAO3t9.jfif](data:image/jpeg;base64,...)

# %% [markdown]
# ## Q3: What is the relationship between Favourite count and Retweet count

# %%
fig = px.scatter(
    data_frame=df,
    x='favorite_count',
    y='retweet_count',
    color='rating_numerator',
    size='retweet_count',
    hover_name='dog_stage',
    labels={
        'retweet_count': 'Retweets',
        'favorite_count': 'Favorites'
    } 
)

fig.update_layout(
    title='Relationship Between Favourite Count and Retweet Count',
    title_x=0.5,
    xaxis_tickfont_size=12,
    xaxis_titlefont_size=16,
    yaxis_titlefont_size=16,
    )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="c49d9da3-e6e7-4b91-9240-0d195a8f9a48" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c49d9da3-e6e7-4b91-9240-0d195a8f9a48")) {                    Plotly.newPlot(                        "c49d9da3-e6e7-4b91-9240-0d195a8f9a48",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>Favorites=%{x}<br>Retweets=%{marker.size}<br>rating_numerator=%{marker.color}<extra></extra>","hovertext":[null,null,null,null,null,null,null,null,"doggo",null,null,"puppo",null,"puppo",null,null,null,null,null,null,null,null,null,null,null,"pupper",null,null,null,null,null,null,null,null,"doggo",null,null,"floofer",null,null,"pupper",null,null,null,null,null,"pupper",null,null,null,null,null,null,null,null,null,"puppo",null,null,null,null,null,null,"pupper",null,null,null,null,null,null,"pupper",null,"puppo",null,"pupper","doggo",null,null,null,null,null,null,"pupper","doggo",null,null,null,null,null,null,"doggo",null,null,null,null,null,null,"puppo",null,null,"pupper",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"puppo",null,"doggo",null,null,null,null,null,null,null,null,null,null,null,null,null,null,"pupper",null,null,null,null,null,null,null,null,null,null,null,null,"pupper",null,null,null,null,null,null,null,null,null,null,null,"doggo",null,null,null,null,"doggo","pupper",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"pupper",null,null,"pupper",null,"doggo",null,null,null,null,null,null,null,null,null,"doggo",null,null,null,null,null,null,null,"pupper","doggo",null,null,null,null,"doggo","doggo","doggo",null,null,null,null,"doggo","pupper",null,null,null,null,null,null,null,"doggo","doggo",null,null,null,null,null,null,null,"doggo",null,null,null,"pupper",null,null,null,null,"doggo","doggo",null,"doggo",null,"doggo",null,null,"puppo",null,"puppo",null,null,"pupper",null,null,null,null,null,"puppo",null,null,null,"pupper",null,null,"doggo",null,"doggo",null,"doggo",null,null,null,null,"puppo",null,null,null,null,"doggo",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"pupper",null,null,"pupper",null,null,null,"doggo",null,null,null,"doggo",null,null,null,null,"doggo",null,"doggo",null,null,null,null,null,null,null,null,null,null,"pupper",null,null,null,null,null,null,null,null,null,null,"pupper",null,null,null,"pupper",null,null,null,null,null,null,null,null,null,null,"puppo","pupper",null,null,null,"puppo",null,null,null,null,null,null,"floofer",null,"doggo",null,null,null,null,null,null,"pupper",null,null,null,null,"doggo",null,null,null,null,null,"doggo",null,null,null,null,null,null,null,null,null,null,null,null,null,"puppo",null,null,null,null,null,null,null,null,null,null,null,null,"puppo",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"puppo",null,null,null,null,null,null,"doggo",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"doggo",null,null,"doggo",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"pupper","pupper",null,null,null,null,null,"pupper","floofer",null,null,null,"doggo",null,null,null,null,"pupper",null,null,null,"pupper",null,null,null,null,null,null,"pupper",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"pupper",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"doggo",null,null,null,null,null,null,null,null,null,null,null,null,"doggo",null,null,null,null,null,null,null,null,null,null,"doggo",nul ...

# %%
p_correlation = df['favorite_count'].corr(df['retweet_count'])
print(p_correlation)
# Out:
# 0.913283914404836

# %% [markdown]
# As expected, there is a strong correlation betweet favourite count and retweet. This means the more people favourite a tweet, the more likely to retweet the tweet.

# %% [markdown]
# ## Conclusion
#
# The datasets were quite robust but had quite a bit of missing values and a quite a bit of errors spread across the datasets which required a bit of wrangling effort.
#
# Despite this missing values and errors, with a bit of wrangling, the dataset was robust enough to get some meaniful insights from it as done above.

# %% [markdown]
# ## Limitations
#
# Due to the large spread within the dataset, some of the datas may be skewed in favour of features with large spread and high standard deviations within their values

# %% [markdown]
# -------------------------------------------------------------

# %% [markdown]
# ##### Downloading dataset files to local system

# %%
# !zip -r /content/datasets.zip /content/datasets/
# Out:
#   adding: content/datasets/ (stored 0%)
#   adding: content/datasets/twitter-archive-enhanced.csv (deflated 77%)
#   adding: content/datasets/wiki_List_of_dog_breeds.html (deflated 84%)
#   adding: content/datasets/image_predictions.tsv (deflated 69%)
#   adding: content/datasets/tweet-json.txt (deflated 94%)
#   adding: content/datasets/twitter_archive_master.csv (deflated 71%)

# %%
from google.colab import files
files.download("/content/datasets.zip")
